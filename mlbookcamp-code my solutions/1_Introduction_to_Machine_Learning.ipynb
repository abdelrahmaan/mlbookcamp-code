# %%
# !pip3 install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=73634f538fcbf8a85f3c21fc2f7ab61df6e6ddb32b9891db51c6f6268bc7ddc9
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...

# %%
import numpy as np
import pandas as pd
import wget

# %% [markdown]
# ## 1. Introduction to Machine Learning

# %% [markdown]
# **1-What's the version of NumPy that you installed?**

# %%
np.__version__
# Out:
# '1.21.6'

# %%
url = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv'
filename = wget.download(url)
data = pd.read_csv(filename)
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %% [markdown]
# **2-How many records are in the dataset?**

# %%
print(len(data))
print(data.shape[0])
# Out:
# 11914
# 11914

# %% [markdown]
# **3-Who are the most frequent car manufacturers (top-3) according to the dataset?**

# %%
pd.DataFrame(data['Make'].value_counts()).T
# Out:
#       Chevrolet  Ford  Volkswagen  Toyota  Dodge  Nissan  GMC  Honda  Mazda  \
# Make       1123   881         809     746    626     558  515    449    423
#
#       Cadillac  ...  Rolls-Royce  Lotus  Tesla  HUMMER  Maybach  Alfa Romeo  \
# Make       397  ...           31     29     18      17       16           5
#
#       McLaren  Spyker  Genesis  Bugatti
# Make        5       3        3        3
#
# [1 rows x 48 columns]

# %%
# the top 3 -> Chevrolet , Ford,  Volkswagen
data['Make'].value_counts()[:3]
# Out:
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Name: Make, dtype: int64

# %% [markdown]
# **4-What's the number of unique Audi car models in the dataset?**

# %%
data[data['Make'] == 'Audi']['Model'].value_counts().sum()
# Out:
# 328

# %%
# 34 unique number
len(set(data[data['Make'] == 'Audi']['Model'].values))
# Out:
# 34

# %% [markdown]
# **5-How many columns in the dataset have missing values?**

# %%
# 5 missing cols
data.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# **6-**
#
# * Find the median value of "Engine Cylinders" column in the dataset.
#
# * Next, calculate the most frequent value of the same "Engine Cylinders".
#
# * Use the fillna method to fill the missing values in "Engine Cylinders" with the most frequent value from the previous step.
#
# * Now, calculate the median value of "Engine Cylinders" once again.
#
#
# Hint: refer to existing `mode` and `median` functions to complete the task.

# %%
# the median
the_median_value = data['Engine Cylinders'].median()
the_median_value
# Out:
# 6.0

# %%
# the most frequent
the_most_frequent = data['Engine Cylinders'].mode()[0]
the_most_frequent
# Out:
# 4.0

# %%
# first, we show if it's have a missing values or not ... it's yes!
data['Engine Cylinders'].isna().sum()
# Out:
# 30

# %%
# fill in missing values with the median
data['Engine Cylinders'] = data['Engine Cylinders'].fillna(the_most_frequent)

# %%
# check if already filled !
data['Engine Cylinders'].isna().sum()
# Out:
# 0

# %%
# 5 missing cols
data.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# **7-**
#
# * Select all the "Lotus" cars from the dataset.
#
# * Select only columns "Engine HP", "Engine Cylinders".
#
# * Now drop all duplicated rows using drop_duplicates method (you should get a dataframe with 9 rows).
#
# * Get the underlying NumPy array. Let's call it X.
#
# * Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
# Invert XTX.
#
# * Create an array y with values [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800].
# Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
#
# * What's the value of the first element of w?
# Note: You just implemented linear regression. We'll talk about it in the next lesson.

# %%
data[data['Make'] == 'Lotus']
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %%
data[["Engine HP", "Engine Cylinders"]].drop_duplicates()
# Out:
#        Engine HP  Engine Cylinders
# 0          335.0               6.0
# 1          300.0               6.0
# 3          230.0               6.0
# 15         320.0               6.0
# 17         172.0               6.0
# ...          ...               ...
# 11640      197.0               5.0
# 11768      410.0               6.0
# 11792       97.0               4.0
# 11885      184.0               6.0
# 11903      394.0               8.0
#
# [567 rows x 2 columns]
